# %% [markdown]
# # Bias-variance tradeoff
# Santiago Hincapie

# %% [markdown]
# Hagamos un pequeño experimento, generemos multiples datasets de entrenamiento $\mathbb{D}_1, \mathbb{D}_2, \dots, \mathbb{D}_M$ y con el entrenemos multiples modelos $f_1, f_2, \dots, f_M$ y observemos como distribucionalmente dichos modelos aproximan la funcion que nos interesa.

# %%
import matplotlib.pyplot as plt
import torch

from src.poly import PolinomialFunction, PolynomialRegression
from src.bias_variance import bias_variance_experiment, plot_bias_variance

# %%
torch.manual_seed(10); # just to have a nice graph

oracle = PolinomialFunction(5, noise_std=0.5)

# %%
model = PolynomialRegression(0)

plot_bias_variance(
    *bias_variance_experiment(
        oracle=oracle, 
        model=model,
        num_train_datasets=100,
        num_train_examples_per_dataset=500
    ),
    dpi=224,
)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
model = PolynomialRegression(3)

plot_bias_variance(
    *bias_variance_experiment(
        oracle=oracle, 
        model=model,
        num_train_datasets=100,
        num_train_examples_per_dataset=500
    ),
    dpi=224
)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
model = PolynomialRegression(4)

plot_bias_variance(
    *bias_variance_experiment(
        oracle=oracle, 
        model=model,
        num_train_examples_per_dataset=500
    ),
    dpi=224
)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
model = PolynomialRegression(5)

plot_bias_variance(
    *bias_variance_experiment(
        oracle=oracle, 
        model=model,
        num_train_examples_per_dataset=500
    ),
    dpi=224
)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
model = PolynomialRegression(7)

plot_bias_variance(
    *bias_variance_experiment(
        oracle=oracle, 
        model=model,
        num_train_examples_per_dataset=500
    ),
    dpi=224
)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# pero.... En el mundo real no tenemos infinitos datasets :c <br>
# ¿Que podemos hacer?

# %% [markdown]
# <img src="https://datacated.com/wp-content/uploads/2019/02/1_9hPX9pAO3jqLrzt0IE3JzA.png" width="2048"/>

# %% [markdown]
# <img src="https://i.imgur.com/tHiVFnM.png" width="1500"/>

# %% [markdown]
# # A jugar!
# # https://playground.tensorflow.org/
